# %%
import folium
m = folium.Map(location = [28.61, 77.23], zoom_start=5)
folium.Marker([28.61, 77.23],popup="New Delhi").add_to(m)

m.save("map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e72b16803b5995faf5f1adc0edaf01b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e72b16803b5995faf5f1adc0edaf01b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e72b16803b5995faf5f1adc0edaf01b = L.map(
#                 &quot;map_9e72b16803b5995faf5f1adc0edaf01b&quot;,
#                 {
#                     center: [28.61, 77.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e356eee437ed9438a2df28a5dca6dba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e356eee437ed9438a2df28a5dca6dba.addTo(map_9e72b16803b5995faf5f1adc0edaf01b);
#
#
#             var marker_2a2b0e97fad772dea9069be2f704a77f = L.marker(
#                 [28.61, 77.23],
#                 {}
#             ).addTo(map_9e72b16803b5995faf5f1adc0edaf01b);
#
#
#         var popup_030c2cdd740dea075e58f94d03ed5602 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2800c3fda8e9360538d711428dabf583 = $(`&lt;div id=&quot;html_2800c3fda8e9360538d711428dabf583&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New Delhi&lt;/div&gt;`)[0];
#                 popup_030c2cdd740dea075e58f94d03ed5602.setContent(html_2800c3fda8e9360538d711428dabf583);
#
#
#
#         marker_2a2b0e97fad772dea9069be2f704a77f.bindPopup(popup_030c2cdd740dea075e58f94d03ed5602)
#         ;
#
#
#
#
#             tile_layer_4e356eee437ed9438a2df28a5dca6dba.addTo(map_9e72b16803b5995faf5f1adc0edaf01b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from folium.plugins import MiniMap, MarkerCluster

# --- Création de la carte principale ---
m = folium.Map(
    location=[28.61, 77.23],  # Coordonnées de New Delhi
    zoom_start=5,
    tiles='CartoDB positron'  # Fond clair et moderne
)

# --- Ajout d'un cluster de marqueurs ---
marker_cluster = MarkerCluster().add_to(m)

# --- Liste de quelques villes en Inde ---
cities = [
    ("New Delhi", [28.61, 77.23], "Capitale de l'Inde"),
    ("Mumbai", [19.07, 72.87], "Centre économique et culturel"),
    ("Bangalore", [12.97, 77.59], "Technologie et innovation"),
    ("Chennai", [13.08, 80.27], "Grande ville portuaire du sud"),
    ("Kolkata", [22.57, 88.36], "Ancienne capitale coloniale")
]

# --- Ajout des marqueurs avec info-bulles et popups ---
for name, coord, desc in cities:
    popup_html = f"""
    <b>{name}</b><br>
    <i>{desc}</i>
    """
    folium.Marker(
        location=coord,
        popup=popup_html,
        tooltip=name,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

# --- Ajout d’une mini-carte en bas à droite ---
minimap = MiniMap(toggle_display=True, position="bottomright")
m.add_child(minimap)

# --- Ajout du contrôle des couches ---
folium.LayerControl().add_to(m)

# --- Sauvegarde et affichage ---
m.save("map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8600ba316e2d85a31b3d252320843887 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8600ba316e2d85a31b3d252320843887&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8600ba316e2d85a31b3d252320843887 = L.map(
#                 &quot;map_8600ba316e2d85a31b3d252320843887&quot;,
#                 {
#                     center: [28.61, 77.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06e309b3e2091e8b7c18a5db0194c848 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06e309b3e2091e8b7c18a5db0194c848.addTo(map_8600ba316e2d85a31b3d252320843887);
#
#
#             var marker_cluster_3ddd8b24a7d74d49fce045cba7365f79 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_f4a363d7d07bbb1178c65a325fe137ad = L.marker(
#                 [28.61, 77.23],
#                 {}
#             ).addTo(marker_cluster_3ddd8b24a7d74d49fce045cba7365f79);
#
#
#             var icon_37f5eae58d2d8d5f6957ffce2ede18a5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f4a363d7d07bbb1178c65a325fe137ad.setIcon(icon_37f5eae58d2d8d5f6957ffce2ede18a5);
#
#
#         var popup_ab0b097e6eb7b2d527b374a2f132964a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_171586248dbf0a97a91977fb6f0afe93 = $(`&lt;div id=&quot;html_171586248dbf0a97a91977fb6f0afe93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;New Delhi&lt;/b&gt;&lt;br&gt;     &lt;i&gt;Capitale de l&#x27;Inde&lt;/i&gt;     &lt;/div&gt;`)[0];
#                 popup_ab0b097e6eb7b2d527b374a2f132964a.setContent(html_171586248dbf0a97a91977fb6f0afe93);
#
#
#
#         marker_f4a363d7d07bbb1178c65a325fe137ad.bindPopup(popup_ab0b097e6eb7b2d527b374a2f132964a)
#         ;
#
#
#
#
#             marker_f4a363d7d07bbb1178c65a325fe137ad.bindTooltip(
#                 `&lt;div&gt;
#                      New Delhi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d50e3acdb68dd160648378a00f1ce009 = L.marker(
#                 [19.07, 72.87],
#                 {}
#             ).addTo(marker_cluster_3ddd8b24a7d74d49fce045cba7365f79);
#
#
#             var icon_b74aa8e27d3659410d8834a5de4f30d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d50e3acdb68dd160648378a00f1ce009.setIcon(icon_b74aa8e27d3659410d8834a5de4f30d4);
#
#
#         var popup_16666ddd49889e742192539f9099c637 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8420f5f86438056e4ef0907bbbab368c = $(`&lt;div id=&quot;html_8420f5f86438056e4ef0907bbbab368c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Mumbai&lt;/b&gt;&lt;br&gt;     &lt;i&gt;Centre économique et culturel&lt;/i&gt;     &lt;/div&gt;`)[0];
#                 popup_16666ddd49889e742192539f9099c637.setContent(html_8420f5f86438056e4ef0907bbbab368c);
#
#
#
#         marker_d50e3acdb68dd160648378a00f1ce009.bindPopup(popup_16666ddd49889e742192539f9099c637)
#         ;
#
#
#
#
#             marker_d50e3acdb68dd160648378a00f1ce009.bindTooltip(
#                 `&lt;div&gt;
#                      Mumbai
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c0d2cbea555e87e0113895789ae345d9 = L.marker(
#                 [12

# %%
import folium
from folium.plugins import MiniMap, MarkerCluster, HeatMap
import requests

# --- Création de la carte principale ---
m = folium.Map(
    location=[22.97, 78.65],  # centre géographique de l'Inde
    zoom_start=5,
    tiles='CartoDB positron'
)

# --- Ajout du cluster de marqueurs ---
marker_cluster = MarkerCluster(name="Villes principales").add_to(m)

# --- Données : villes et populations approximatives ---
cities = [
    ("New Delhi", [28.61, 77.23], "Capitale de l'Inde", 33_000_000),
    ("Mumbai", [19.07, 72.87], "Centre économique", 25_000_000),
    ("Bangalore", [12.97, 77.59], "Technologie et innovation", 13_000_000),
    ("Chennai", [13.08, 80.27], "Ville portuaire du sud", 11_000_000),
    ("Kolkata", [22.57, 88.36], "Ancienne capitale coloniale", 14_000_000),
    ("Hyderabad", [17.38, 78.48], "Technopôle en pleine croissance", 12_000_000),
]

# --- Ajout des marqueurs ---
for name, coord, desc, pop in cities:
    popup_html = f"""
    <b>{name}</b><br>
    <i>{desc}</i><br>
    Population : {pop:,} habitants
    """
    folium.Marker(
        location=coord,
        popup=popup_html,
        tooltip=name,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

# --- Ajout de la carte de chaleur ---
heat_data = [[lat, lon, pop / 10_000_000] for _, [lat, lon], _, pop in cities]
HeatMap(heat_data, name="Carte de chaleur").add_to(m)

# --- Ajout du contour du pays via GeoJSON ---
try:
    url = "https://raw.githubusercontent.com/johan/world.geo.json/master/countries/IND.geo.json"
    india_geojson = requests.get(url).json()
    folium.GeoJson(
        india_geojson,
        name="Frontières de l'Inde",
        style_function=lambda x: {
            'fillColor': '#00000000',  # transparent
            'color': '#ff7800',
            'weight': 2,
            'fillOpacity': 0
        }
    ).add_to(m)
except Exception as e:
    print("⚠️ Impossible de charger le GeoJSON :", e)

# --- Ajout de la mini-carte ---
minimap = MiniMap(toggle_display=True, position="bottomright")
m.add_child(minimap)

# --- Ajout du contrôle de couches ---
folium.LayerControl().add_to(m)

# --- Sauvegarde ---
m.save("map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7531b6e03a1c0b9661d6a7f6d442c27c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7531b6e03a1c0b9661d6a7f6d442c27c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7531b6e03a1c0b9661d6a7f6d442c27c = L.map(
#                 &quot;map_7531b6e03a1c0b9661d6a7f6d442c27c&quot;,
#                 {
#                     center: [22.97, 78.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bb8b62b59e5e6268589ad94483b0f8e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2bb8b62b59e5e6268589ad94483b0f8e.addTo(map_7531b6e03a1c0b9661d6a7f6d442c27c);
#
#
#             var marker_cluster_a61a832e44d41c4cdb550627b19183b6 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_f43103f12f69316907661163cbcebe2a = L.marker(
#                 [28.61, 77.23],
#                 {}
#             ).addTo(marker_cluster_a61a832e44d41c4cdb550627b19183b6);
#
#
#             var icon_8eec9a79346da34fe69d0a7b45738cb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f43103f12f69316907661163cbcebe2a.setIcon(icon_8eec9a79346da34fe69d0a7b45738cb5);
#
#
#         var popup_acff0120686462ab893aeb6d8a303d3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9d07f4417fff23b98df9237edb00d26 = $(`&lt;div id=&quot;html_d9d07f4417fff23b98df9237edb00d26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;New Delhi&lt;/b&gt;&lt;br&gt;     &lt;i&gt;Capitale de l&#x27;Inde&lt;/i&gt;&lt;br&gt;     Population : 33,000,000 habitants     &lt;/div&gt;`)[0];
#                 popup_acff0120686462ab893aeb6d8a303d3a.setContent(html_d9d07f4417fff23b98df9237edb00d26);
#
#
#
#         marker_f43103f12f69316907661163cbcebe2a.bindPopup(popup_acff0120686462ab893aeb6d8a303d3a)
#         ;
#
#
#
#
#             marker_f43103f12f69316907661163cbcebe2a.bindTooltip(
#                 `&lt;div&gt;
#                      New Delhi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8ab4f1a5a1a9a9ff19192fb5702f238a = L.marker(
#                 [19.07, 72.87],
#                 {}
#             ).addTo(marker_cluster_a61a832e44d41c4cdb550627b19183b6);
#
#
#             var icon_6c6541dee861d76f5df5700af9ba2d97 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8ab4f1a5a1a9a9ff19192fb5702f238a.setIcon(icon_6c6541dee861d76f5df5700af9ba2d97);
#
#
#         var popup_595f153f0972d977d6bc352061ca0cb0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bf866707d6fe1c58099b382fe4a7e7b = $(`&lt;div id=&quot;html_5bf866707d6fe1c58099b382fe4a7e7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Mumbai&lt;/b&gt;&lt;br&gt;     &lt;i&gt;Centre économique&lt;/i&gt;&lt;br&gt;     Population : 25,000,000 habitants     &lt;/div&gt;`)[0];
#                 popup_595f153f0972d977d6bc352061ca0cb0.setContent(html_5bf866707d6fe1c58099b382fe4a7e7b);
#
#
#
#         marker_8ab4f1a5a1a9a9ff19192fb5702f238a.bindPopup(popup_595f153f0972d977d6bc352061ca0cb0)
#         ;
#
#
#
#
#             marker_8ab4f1a5a1a9a9ff19192fb5702f238a.bindTooltip(

# %%
import folium
from folium.plugins import MiniMap, MarkerCluster, HeatMap
import requests

# ============================
# 🌍 1. Création de la carte principale
# ============================
m = folium.Map(
    location=[22.97, 78.65],  # centre géographique de l’Inde
    zoom_start=5,
    tiles=None  # on ajoute les fonds manuellement
)

# --- Fonds de carte disponibles ---
folium.TileLayer('CartoDB positron', name='Fond clair').add_to(m)
folium.TileLayer('Esri.WorldImagery', name='Fond satellite').add_to(m)

# ============================
# 🏙️ 2. Données des villes
# ============================
cities = [
    ("New Delhi", [28.61, 77.23], "Capitale de l'Inde", 33_000_000),
    ("Mumbai", [19.07, 72.87], "Centre économique", 25_000_000),
    ("Bangalore", [12.97, 77.59], "Technologie et innovation", 13_000_000),
    ("Chennai", [13.08, 80.27], "Ville portuaire du sud", 11_000_000),
    ("Kolkata", [22.57, 88.36], "Ancienne capitale coloniale", 14_000_000),
    ("Hyderabad", [17.38, 78.48], "Technopôle en pleine croissance", 12_000_000),
]

# ============================
# 📍 3. Marqueurs groupés
# ============================
marker_cluster = MarkerCluster(name="Villes principales").add_to(m)

for name, coord, desc, pop in cities:
    popup_html = f"""
    <b>{name}</b><br>
    <i>{desc}</i><br>
    Population : {pop:,} habitants
    """
    folium.Marker(
        location=coord,
        popup=popup_html,
        tooltip=name,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

# ============================
# 🔥 4. Carte de chaleur
# ============================
heat_data = [[lat, lon, pop / 10_000_000] for _, [lat, lon], _, pop in cities]
HeatMap(heat_data, name="Carte de chaleur").add_to(m)

# ============================
# 🧭 5. Frontières de l’Inde (GeoJSON)
# ============================
try:
    url = "https://raw.githubusercontent.com/johan/world.geo.json/master/countries/IND.geo.json"
    india_geojson = requests.get(url).json()
    folium.GeoJson(
        india_geojson,
        name="Frontières de l'Inde",
        style_function=lambda x: {
            'fillColor': '#00000000',  # transparent
            'color': '#ff6600',
            'weight': 2,
            'fillOpacity': 0.1
        }
    ).add_to(m)
except Exception as e:
    print("⚠️ Impossible de charger le GeoJSON :", e)

# ============================
# 🛣️ 6. Tracés d’itinéraires
# ============================
route_coords = [coord for _, coord, _, _ in cities]
folium.PolyLine(
    route_coords,
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="10",
    tooltip="Itinéraire principal entre les grandes villes"
).add_to(m)

# ============================
# 🗺️ 7. Mini-map et contrôle
# ============================
minimap = MiniMap(toggle_display=True, position="bottomright")
m.add_child(minimap)
folium.LayerControl(collapsed=False).add_to(m)

# ============================
# 💾 8. Sauvegarde
# ============================
m.save("map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edc6b9f5036bd4fc2f34a3072d45529f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edc6b9f5036bd4fc2f34a3072d45529f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edc6b9f5036bd4fc2f34a3072d45529f = L.map(
#                 &quot;map_edc6b9f5036bd4fc2f34a3072d45529f&quot;,
#                 {
#                     center: [22.97, 78.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f33dfe56be5696a621e2eb677de85e16 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f33dfe56be5696a621e2eb677de85e16.addTo(map_edc6b9f5036bd4fc2f34a3072d45529f);
#
#
#             var tile_layer_07ae040892c902884b99c3c6029aa75b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_07ae040892c902884b99c3c6029aa75b.addTo(map_edc6b9f5036bd4fc2f34a3072d45529f);
#
#
#             var marker_cluster_9f43483f24c012259af9f4df0a0b0606 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_1ab0e943eeebd90e8f4e6161dae8aebb = L.marker(
#                 [28.61, 77.23],
#                 {}
#             ).addTo(marker_cluster_9f43483f24c012259af9f4df0a0b0606);
#
#
#             var icon_e7856ccb272b9b56b12cccc7ed55c76b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1ab0e943eeebd90e8f4e6161dae8aebb.setIcon(icon_e7856ccb272b9b56b12cccc7ed55c76b);
#
#
#         var popup_ed965bf9e54efe0134e64606e7b9ccc6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f867f9571a15ae72dbe18a606b1a2877 = $(`&lt;div id=&quot;html_f867f9571a15ae72dbe18a606b1a2877&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;New Delhi&lt;/b&gt;&lt;br&gt;     &lt;i&gt;Capitale de l&#x27;Inde&lt;/i&gt;&lt;br&gt;     Population : 33,000,000 habitants     &lt;/div&gt;`)[0];
#                 popup_ed965bf9e54efe0134e64606e7b9ccc6.setContent(html_f867f9571a15ae72dbe18a606b1a2877);
#
#
#
#         marker_1ab0e943eeebd90e8f4e6161dae8aebb.bindPopup(popup_ed965bf9e54efe0134e64606e7b9ccc6)
#         ;
#
#
#
#
#             marker_1ab0e943eeebd90e8f4e6161dae8aebb.bindTooltip(
#                 `&lt;div&gt;
#                      New Delhi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4a3b923c4c732b18d38756a1d7f1cb47 = L.marker(
#                 [19.07, 72.87],
#                 {}
#             ).addTo(marker_cluster_9f43483f24c012259af9f4df0a0b0606);
#
#
#             var icon_4d6503bb4a3d14920fb81045bf6b2e09 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a3b923c4c732b18d38756a1d7f1cb47.setIcon(icon_4d6503bb4a3d14920fb81045bf6b2e09);
#
#
#         var popup_9ff041cc484e8f101d65388b835a3

# %% [markdown]
# # `map_india.py`

# %%
import folium
from folium.plugins import MiniMap, MarkerCluster, HeatMap
import requests

# ============================
# 🌍 1. Création de la carte principale
# ============================
m = folium.Map(
    location=[22.97, 78.65],  # centre géographique de l’Inde
    zoom_start=5,
    tiles=None  # on ajoute les fonds manuellement
)

# --- Fonds de carte disponibles ---
folium.TileLayer('CartoDB positron', name='Fond clair').add_to(m)
folium.TileLayer('Esri.WorldImagery', name='Fond satellite').add_to(m)

# ============================
# 🏙️ 2. Données des villes
# ============================
cities = [
    ("New Delhi", [28.61, 77.23], "Capitale de l'Inde", 33_000_000),
    ("Mumbai", [19.07, 72.87], "Centre économique", 25_000_000),
    ("Bangalore", [12.97, 77.59], "Technologie et innovation", 13_000_000),
    ("Chennai", [13.08, 80.27], "Ville portuaire du sud", 11_000_000),
    ("Kolkata", [22.57, 88.36], "Ancienne capitale coloniale", 14_000_000),
    ("Hyderabad", [17.38, 78.48], "Technopôle en pleine croissance", 12_000_000),
]

# ============================
# 📍 3. Marqueurs groupés
# ============================
marker_cluster = MarkerCluster(name="Villes principales").add_to(m)

for name, coord, desc, pop in cities:
    popup_html = f"""
    <b>{name}</b><br>
    <i>{desc}</i><br>
    Population : {pop:,} habitants
    """
    folium.Marker(
        location=coord,
        popup=popup_html,
        tooltip=name,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

# ============================
# 🔥 4. Carte de chaleur
# ============================
heat_data = [[lat, lon, pop / 10_000_000] for _, [lat, lon], _, pop in cities]
HeatMap(heat_data, name="Carte de chaleur").add_to(m)

# ============================
# 🧭 5. Frontières de l’Inde (GeoJSON)
# ============================
try:
    url = "https://raw.githubusercontent.com/johan/world.geo.json/master/countries/IND.geo.json"
    india_geojson = requests.get(url).json()
    folium.GeoJson(
        india_geojson,
        name="Frontières de l'Inde",
        style_function=lambda x: {
            'fillColor': '#00000000',  # transparent
            'color': '#ff6600',
            'weight': 2,
            'fillOpacity': 0.1
        }
    ).add_to(m)
except Exception as e:
    print("⚠️ Impossible de charger le GeoJSON :", e)

# ============================
# 🛣️ 6. Tracés d’itinéraires
# ============================
route_coords = [coord for _, coord, _, _ in cities]
folium.PolyLine(
    route_coords,
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="10",
    tooltip="Itinéraire principal entre les grandes villes"
).add_to(m)

# ============================
# 🗺️ 7. Mini-map et contrôle
# ============================
minimap = MiniMap(toggle_display=True, position="bottomright")
m.add_child(minimap)
folium.LayerControl(collapsed=False).add_to(m)

# ============================
# 🧾 8. Légende personnalisée
# ============================
legend_html = """
<div style="
    position: fixed; 
    bottom: 30px; left: 30px; width: 230px; 
    background-color: white;
    border: 2px solid grey;
    z-index: 9999; 
    font-size: 14px;
    box-shadow: 2px 2px 5px rgba(0,0,0,0.3);
    border-radius: 10px;
    padding: 10px;
">
    <h4 style="margin-top:0; text-align:center;">🗺️ Légende</h4>
    <p><i style="color:#ff6600;">▭</i>  Frontières de l’Inde</p>
    <p><i style="color:red;">▬ ▬ ▬</i>  Itinéraire principal</p>
    <p><i style="color:blue;" class="fa fa-map-marker"></i>  Villes principales</p>
    <p><i style="background:linear-gradient(to right, yellow, red); 
                padding:2px 10px; border-radius:3px;"></i>  Densité de population (carte de chaleur)</p>
    <p><b>🛰️ Fond satellite</b> ou <b>🗺️ Fond clair</b> disponibles</p>
</div>
"""
m.get_root().html.add_child(folium.Element(legend_html))

# ============================
# 💾 9. Sauvegarde et affichage
# ============================
m.save("map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c861312bbbf91c05cb985ae31f0d33f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 30px; left: 30px; width: 230px;
#     background-color: white;
#     border: 2px solid grey;
#     z-index: 9999;
#     font-size: 14px;
#     box-shadow: 2px 2px 5px rgba(0,0,0,0.3);
#     border-radius: 10px;
#     padding: 10px;
# &quot;&gt;
#     &lt;h4 style=&quot;margin-top:0; text-align:center;&quot;&gt;🗺️ Légende&lt;/h4&gt;
#     &lt;p&gt;&lt;i style=&quot;color:#ff6600;&quot;&gt;▭&lt;/i&gt;  Frontières de l’Inde&lt;/p&gt;
#     &lt;p&gt;&lt;i style=&quot;color:red;&quot;&gt;▬ ▬ ▬&lt;/i&gt;  Itinéraire principal&lt;/p&gt;
#     &lt;p&gt;&lt;i style=&quot;color:blue;&quot; class=&quot;fa fa-map-marker&quot;&gt;&lt;/i&gt;  Villes principales&lt;/p&gt;
#     &lt;p&gt;&lt;i style=&quot;background:linear-gradient(to right, yellow, red);
#                 padding:2px 10px; border-radius:3px;&quot;&gt;&lt;/i&gt;  Densité de population (carte de chaleur)&lt;/p&gt;
#     &lt;p&gt;&lt;b&gt;🛰️ Fond satellite&lt;/b&gt; ou &lt;b&gt;🗺️ Fond clair&lt;/b&gt; disponibles&lt;/p&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c861312bbbf91c05cb985ae31f0d33f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c861312bbbf91c05cb985ae31f0d33f = L.map(
#                 &quot;map_8c861312bbbf91c05cb985ae31f0d33f&quot;,
#                 {
#                     center: [22.97, 78.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b365f838ec32b524525078281c0aaa0e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b365f838ec32b524525078281c0aaa0e.addTo(map_8c861312bbbf91c05cb985ae31f0d33f);
#
#
#             var tile_layer_9c238762a68db60c1548a43eff2fdf2b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9c238762a68db60c1548a43eff2fdf2b.addTo(map_8c861312bbbf91c05cb985ae31f0d33f);
#
#
#             var marker_cluster_09492629a7b1af955bb62b375d6b2a40 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_120ca46ebf414313fdd209a03aa86adb = L.marker(
#                 [28.61, 77.23],
#                 {}
#             ).addTo(marker_cluster_09492629a7b1af955bb62b375d6b2a40);
#
#
#             var icon_f356288c0033f9e56eb8b57cec3b4291 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_120ca46ebf414313fdd209a03aa86adb.setIcon(icon_f356288c0033f9e56eb8b57cec3b4291);
#
#
#         var popup_81e1e56643dca1c59a0538d6c51faba5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c80366e331febdd3ffe3e5205e33796c = $(`&lt;div id=&quot;html_c80366e331febdd3ffe3e5205e33796c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;New Delhi&lt;/b&gt;&lt;br&gt;     &lt;i&gt;Capitale de l&#x27;Inde&lt;/i&gt;&lt;br&gt;     Population : 33,000,000 habitants     &lt;/div&gt;`)[0];
#                 popup_81e1e56643dca1c59a0538d6c51faba5.setContent(html_c80366e331febdd3ffe3e5205e33796c);
#
#
#
#         marker_120c

# %%
#! python3 map_india.py
# !open map.html
